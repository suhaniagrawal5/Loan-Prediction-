# %%
import numpy as np
import pandas as pd
import sklearn as sk

# %%
df=pd.read_csv('train_ctrUa4K.csv')
df.head()
# Out:
#     Loan_ID Married     Education Self_Employed  ApplicantIncome  \
# 0  LP001002      No      Graduate            No             5849
# 1  LP001003     Yes      Graduate            No             4583
# 2  LP001005     Yes      Graduate           Yes             3000
# 3  LP001006     Yes  Not Graduate            No             2583
# 4  LP001008      No      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Loan_Status  loan_in_years  \
# 0                0.0         0.0             360.0           Y             30
# 1             1508.0       128.0             360.0           N             30
# 2                0.0        66.0             360.0           Y             30
# 3             2358.0       120.0             360.0           Y             30
# 4                0.0       141.0             360.0           Y             30
#
#    Loan_total  total_incone_per_annum
# 0           0                 70188.0
# ...

# %%
df2=df.drop(['Married','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term'],axis=1)
df2.head()
# Out:
#     Loan_ID     Education Self_Employed Loan_Status  loan_in_years  \
# 0  LP001002      Graduate            No           Y             30
# 1  LP001003      Graduate            No           N             30
# 2  LP001005      Graduate           Yes           Y             30
# 3  LP001006  Not Graduate            No           Y             30
# 4  LP001008      Graduate            No           Y             30
#
#    Loan_total  total_incone_per_annum
# 0           0                 70188.0
# 1      128000                 73092.0
# 2       66000                 36000.0
# 3      120000                 59292.0
# 4      141000                 72000.0

# %%
df2.rename(columns={'total_incone_per_annum':'total_income_per_annum'},inplace=True)
df2.head()
# Out:
#     Loan_ID     Education Self_Employed Loan_Status  loan_in_years  \
# 0  LP001002      Graduate            No           Y             30
# 1  LP001003      Graduate            No           N             30
# 2  LP001005      Graduate           Yes           Y             30
# 3  LP001006  Not Graduate            No           Y             30
# 4  LP001008      Graduate            No           Y             30
#
#    Loan_total  total_income_per_annum
# 0           0                 70188.0
# 1      128000                 73092.0
# 2       66000                 36000.0
# 3      120000                 59292.0
# 4      141000                 72000.0

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2[['loan_in_years','Loan_total','total_income_per_annum']]
y=df2['Loan_Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= 0.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.6956521739130435
